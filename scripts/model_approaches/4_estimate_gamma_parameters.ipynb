# %%
import numpy as np
import pandas as pd
import math
import random
import statistics
import importlib

from utils import math_expressions as mexpr, methods

# %%
test_df = pd.read_csv('../../data/gen_test.csv')
display(test_df.head())
# Out:
#    alpha  beta     h   c   N  n    mean_n     std_n  alpha_hat  beta_hat  \
# 0      2   1.0  0.40  25  31  5  1.608631  1.188836   1.830919  0.878592
# 1      2   1.5  0.40  30  14  5  4.009268  2.903299   1.906982  2.102416
# 2      5   1.0  0.10  20  12  5  6.821328  3.360037   4.121449  1.655080
# 3      2   1.0  0.05  25  46  5  1.505001  0.868517   3.002733  0.501210
# 4      2   2.0  0.40  15  36  5  3.557228  2.238024   2.526352  1.408049
#
#                                        intervals_str           u      u_star  \
# 0  0.003058540635843962_2.043043768618266_0.87786...   76.385318   49.639974
# 1  6.38314683676832_6.791394935951803_0.294959015...   35.315328   28.897170
# 2  2.3952951439570325_10.96045323453524_4.9239916...   62.303999   43.872717
# 3  0.9910707518986788_0.8247997136843997_2.295715...   76.928575   69.443922
# 4  7.084869757006029_2.2238474479686117_1.1614816...  152.382992  132.364109
#
#    u_star_hat         z  optimal_cost  actual_cost
# 0   38.901501  1.276043     10.698138    14.993527
# 1   39.815962  0.725768      2.567263    30.000000
# 2   59.535043  0.736923      1.843128     0.276896
# 3   54.293023  1.279058      0.374233     1.131778
# 4  116.206029  1.139047      8.007553    14.470785

# %%
methods.plot_plotly(data=test_df['actual_cost'], data_label='Actual Cost')
methods.plot_plotly(data=test_df['optimal_cost'], data_label='Optimal Cost')
methods.multi_plot_plotly(data=[test_df['optimal_cost'], test_df['actual_cost']], data_label=['Optimal Cost', 'Actual Cost'])
